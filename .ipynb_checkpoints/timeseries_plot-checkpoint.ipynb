# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
import requests

#url = 'https://raw.githubusercontent.com/oktadev/blazor-example/master/OktaBlazor/wwwroot/sample-data/weather.json'


df = pd.read_json('data.json')
x = df['date']
y = df['temperatureF']

# %%
fig, ax = plt.subplots()
ax.plot(x,y)
ax.set_title('time_series_plot')
ax.set_xlabel('date')
ax.set_ylabel('temperatureF')
# Out:
# Text(0, 0.5, 'temperatureF')
